# %% [markdown]
# <a href="https://colab.research.google.com/github/wlgns222/roka-ai-study/blob/main/ROKA_AI_STD1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ch3.신경망

# %%
# ==========================================
# 환경 설정: GitHub 저장소 클론 및 경로 추가
# ==========================================
import os
import sys

# 책의 소스 코드가 들어있는 저장소를 클론
# !git clone https://github.com/WegraLee/deep-learning-from-scratch.git

# %cd deep-learning-from-scratch

sys.path.append(os.getcwd())

import numpy as np
from dataset.mnist import load_mnist
from PIL import Image

(x_train, t_train), (x_test, t_test) = load_mnist(flatten=True, normalize=True, one_hot_label=False)

print("--- Data Shapes ---")
print(f"x_train (훈련 데이터): {x_train.shape}")  # (60000, 784)
print(f"t_train (훈련 레이블): {t_train.shape}")  # (60000,)
print(f"x_test  (시험 데이터): {x_test.shape}")   # (10000, 784)
print(f"t_test  (시험 레이블): {t_test.shape}")   # (10000,)
print("-------------------")
# Out:
# Cloning into 'deep-learning-from-scratch'...
# remote: Enumerating objects: 1118, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 1118 (delta 142), reused 129 (delta 129), pack-reused 943 (from 2)
# Receiving objects: 100% (1118/1118), 52.68 MiB | 33.80 MiB/s, done.
# Resolving deltas: 100% (645/645), done.
# /content/deep-learning-from-scratch/deep-learning-from-scratch/deep-learning-from-scratch
# --- Data Shapes ---
# x_train (훈련 데이터): (60000, 784)
# t_train (훈련 레이블): (60000,)
# x_test  (시험 데이터): (10000, 784)
# t_test  (시험 레이블): (10000,)
# -------------------
